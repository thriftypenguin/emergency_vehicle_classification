# %%
import librosa
import pandas as pd
import numpy as np
import scipy.io.wavfile as wav
import os
import csv
import warnings
warnings.filterwarnings('ignore')

# %%
# Generating new .csv files for ambulance
file = open('./datasets/Jerry_updated_datasets/ambulance_dataset.csv', 'w', newline='')

g = "Emergency_Vehicle_Sirens"
for filename in os.listdir(f'./datasets/my_testing/{g}'):
    songname = f'./datasets/my_testing/{g}/{filename}'
    y, sr = librosa.load(songname, mono=True, duration=1.2)
    rmse = librosa.feature.rms(y=y)
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    zcr = librosa.feature.zero_crossing_rate(y)
    mfcc = librosa.feature.mfcc(y=y, sr=sr)
    to_append = f'{filename} {np.mean(chroma_stft)} {np.mean(rmse)} {np.mean(spec_cent)} {np.mean(spec_bw)} {np.mean(rolloff)} {np.mean(zcr)}'
    for e in mfcc:
        to_append += f' {np.mean(e)}'
    to_append += f' {g}'
    file = open('./datasets/Jerry_updated_datasets/ambulance_dataset.csv', 'a', newline='')
    with file:
        writer = csv.writer(file)
        writer.writerow(to_append.split())

col_names = ["filename","chroma_stft","rmse","spectral_centroid","spectral_bandwidth","rolloff","zero_crossing_rate","mfcc1","mfcc2","mfcc3","mfcc4","mfcc5","mfcc6","mfcc7","mfcc8","mfcc9","mfcc10","mfcc11","mfcc12","mfcc13","mfcc14","mfcc15","mfcc16","mfcc17","mfcc18","mfcc19","mfcc20","label" ]
data = pd.read_csv("./datasets/Jerry_updated_datasets/ambulance_dataset.csv", names=col_names)

print(data.shape)
data.head()
# Out:
# (932, 28)
#            filename  chroma_stft      rmse  spectral_centroid  \
# 0    ambulance1.wav     0.139516  0.698226        1504.983714
# 1   ambulance10.wav     0.257202  0.154136        1405.205729
# 2  ambulance100.wav     0.289014  0.343361        1408.040089
# 3  ambulance101.wav     0.289925  0.291035        1775.381125
# 4  ambulance102.wav     0.298852  0.309095        1578.495015
#
#    spectral_bandwidth      rolloff  zero_crossing_rate       mfcc1  \
# 0          132.931775  1535.483023            0.132193 -399.741699
# 1         1404.868377  2640.509033            0.072416 -218.852631
# 2         1248.953452  2425.798152            0.104389  -63.013569
# 3         1632.580186  3167.037260            0.111187  -16.747330
# 4         1555.881249  3025.415039            0.092285  -34.618477
#
#         mfcc2      mfcc3  ...    mfcc12     mfcc13    mfcc14     mfcc15  \
# 0   22.808897 -51.959656  ... -4.915035 -28.968569 -9.729029  17.305546
# ...

# %%
# Write ambulance dataframe to csv
data.to_csv('./datasets/Jerry_updated_datasets/ambulance_dataset.csv', index=False)

# %%
# Generating new .csv files for road noise
file_1 = open('./datasets/Jerry_updated_datasets/road_dataset.csv', 'w', newline='')

k = "Road_Noises"
for filename in os.listdir(f'./datasets/my_testing/{k}'):
    audioname = f'./datasets/my_testing/{k}/{filename}'
    y, sr = librosa.load(audioname, mono=True, duration=42)
    rmse = librosa.feature.rms(y=y)
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    zcr = librosa.feature.zero_crossing_rate(y)
    mfcc = librosa.feature.mfcc(y=y, sr=sr)
    to_append = f'{filename} {np.mean(chroma_stft)} {np.mean(rmse)} {np.mean(spec_cent)} {np.mean(spec_bw)} {np.mean(rolloff)} {np.mean(zcr)}'
    for e in mfcc:
        to_append += f' {np.mean(e)}'
    to_append += f' {k}'
    file_1 = open('./datasets/Jerry_updated_datasets/road_dataset.csv', 'a', newline='')
    with file_1:
        writer = csv.writer(file_1)
        writer.writerow(to_append.split())

col_names = ["filename","chroma_stft","rmse","spectral_centroid","spectral_bandwidth","rolloff","zero_crossing_rate","mfcc1","mfcc2","mfcc3","mfcc4","mfcc5","mfcc6","mfcc7","mfcc8","mfcc9","mfcc10","mfcc11","mfcc12","mfcc13","mfcc14","mfcc15","mfcc16","mfcc17","mfcc18","mfcc19","mfcc20","label" ]
data_1 = pd.read_csv("./datasets/Jerry_updated_datasets/road_dataset.csv", names=col_names)

print(data_1.shape)
data_1.head()
# Out:
# (902, 28)
#       filename  chroma_stft      rmse  spectral_centroid  spectral_bandwidth  \
# 0    road1.wav     0.517742  0.305894         886.739551         1578.777002
# 1   road10.wav     0.517742  0.305894         886.739551         1578.777002
# 2  road100.wav     0.693476  0.058234        3303.240683         2592.596402
# 3  road101.wav     0.658950  0.077092        1205.446119         1742.785430
# 4  road102.wav     0.593435  0.106416        1063.908138         1680.004602
#
#        rolloff  zero_crossing_rate       mfcc1       mfcc2      mfcc3  ...  \
# 0  1764.324887            0.012647 -121.924667  161.685532  -2.984197  ...
# 1  1764.324887            0.012647 -121.924667  161.685532  -2.984197  ...
# 2  6314.649287            0.198243 -119.120773   46.943718 -32.936520  ...
# 3  2243.303317            0.035050 -203.116531  146.372131 -21.788160  ...
# 4  2019.659500            0.023835 -207.438705  150.211395 -14.793515  ...
#
# ...

# %%
# Write noise dataframe to csv
data_1.to_csv('./datasets/Jerry_updated_datasets/road_dataset.csv', index=False)
